# %%
import sympy as sym
from sympy import pi
import numpy as np

# %%
t= sym.symbols('t')
x = sym.Piecewise((-1, t<0),(1, t>0))
ser = sym.fourier_series(x, (t, -pi, pi))

# %%
ser.truncate(5)
# Out:
# 4*sin(t)/pi + 4*sin(3*t)/(3*pi) + 4*sin(5*t)/(5*pi) + 4*sin(7*t)/(7*pi) + 4*sin(9*t)/(9*pi)

# %%
sym.plot(ser.truncate(3), (t, -pi, pi));

# %%
x1 = sym.Piecewise((-t-2, ((t >=-2)&(t<=-1))),
                   (t, ((t>=-1)&(t<=1))),
                   (-t+2, ((t>=1)& (t<=2))))

# %%
ser1 = sym.fourier_series(x1, (t, -2, 2))

# %%
ser1.truncate(4)
# Out:
# 8*sin(pi*t/2)/pi**2 - 8*sin(3*pi*t/2)/(9*pi**2) + 8*sin(5*pi*t/2)/(25*pi**2) - 8*sin(7*pi*t/2)/(49*pi**2)

# %%
sym.plot(ser1.truncate(10), (t, -pi, pi))

# %%
from cmath import exp
for i in np.arange(-20, 20, 1):
    x2 = sym.Piecewise(exp(-i*2*pi*t), (t>=-2)&(t<=2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\nextonPy\fourier_series.ipynb Cell 9 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/nextonPy/fourier_series.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> from cmath import exp
#       <a href='vscode-notebook-cell:/d%3A/nextonPy/fourier_series.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> for i in np.arange(-20, 20, 1):
# ----> <a href='vscode-notebook-cell:/d%3A/nextonPy/fourier_series.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a>     x2 = sym.Piecewise(exp(-i*2*pi*t), (t>=-2)&(t<=2))
#
# File c:\Users\sudipnext\AppData\Local\Programs\Python\Python310\lib\site-packages\sympy\core\expr.py:356, in Expr.__complex__(self)
#     354 result = self.evalf()
#     355 re, im = result.as_real_imag()
# --> 356 return complex(float(re), float(im))
#
# File c:\Users\sudipnext\AppData\Local\Programs\Python\Python310\lib\site-packages\sympy\core\expr.py:351, in Expr.__float__(self)
#     349 if result.is_number and result.as_real_imag()[1]:
#     350     raise TypeError("Cannot convert complex to float")
# --> 351 raise TypeError("Cannot convert expression to float")
#
# TypeError: Cannot convert expression to float

# %%
ser2 = sym.fourier_series(x2, (t, -2, 2))

# %%
sym.plot(ser2.truncate(10), (t, -pi, pi))
