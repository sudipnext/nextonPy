# %%
import pandas as pd

# %%
df = pd.read_csv('anime.csv')

# %%
df
# Out:
#                    name  height   category  \
# 0        Gintoki Sakata   177.0  fictional
# 1     Shinpachi Shimura   166.0  fictional
# 2                Kagura   155.0  fictional
# 3     Shinsuke Takasugi   170.0  fictional
# 4       Kotarou Katsura   175.0  fictional
# ...                 ...     ...        ...
# 1632    Hikari Kohinata   148.0  fictional
# 1633               Mine   155.0  fictional
# 1634            Esdeath   170.0  fictional
# 1635           Cornelia   168.0  fictional
# 1636            Najasho   162.0  fictional
#
#                                                 subcat1 subcat2  \
# 0                                     Gintama THE FINAL   anime
# 1                                     Gintama THE FINAL   anime
# 2                                     Gintama THE FINAL   anime
# 3                                     Gintama THE FINAL   anime
# 4                                     Gintama THE FINAL   anime
# ...

# %%
df['swap'] = df['subcat1']
df['swap2'] = df['subcat2']
df['subcat1'] = df['swap2']
df['subcat2'] = df['swap']

# %%
df
# Out:
#                    name  height   category subcat1  \
# 0        Gintoki Sakata   177.0  fictional   anime
# 1     Shinpachi Shimura   166.0  fictional   anime
# 2                Kagura   155.0  fictional   anime
# 3     Shinsuke Takasugi   170.0  fictional   anime
# 4       Kotarou Katsura   175.0  fictional   anime
# ...                 ...     ...        ...     ...
# 1632    Hikari Kohinata   148.0  fictional   anime
# 1633               Mine   155.0  fictional   anime
# 1634            Esdeath   170.0  fictional   anime
# 1635           Cornelia   168.0  fictional   anime
# 1636            Najasho   162.0  fictional   anime
#
#                                                 subcat2  \
# 0                                     Gintama THE FINAL
# 1                                     Gintama THE FINAL
# 2                                     Gintama THE FINAL
# 3                                     Gintama THE FINAL
# 4                                     Gintama THE FINAL
# ...

# %%
df.drop(columns=['swap', 'swap2'], inplace=True)

# %%
df.drop_duplicates(subset='name')
# Out:
#                    name  height   category subcat1  \
# 0        Gintoki Sakata   177.0  fictional   anime
# 1     Shinpachi Shimura   166.0  fictional   anime
# 2                Kagura   155.0  fictional   anime
# 3     Shinsuke Takasugi   170.0  fictional   anime
# 4       Kotarou Katsura   175.0  fictional   anime
# ...                 ...     ...        ...     ...
# 1632    Hikari Kohinata   148.0  fictional   anime
# 1633               Mine   155.0  fictional   anime
# 1634            Esdeath   170.0  fictional   anime
# 1635           Cornelia   168.0  fictional   anime
# 1636            Najasho   162.0  fictional   anime
#
#                                                 subcat2  \
# 0                                     Gintama THE FINAL
# 1                                     Gintama THE FINAL
# 2                                     Gintama THE FINAL
# 3                                     Gintama THE FINAL
# 4                                     Gintama THE FINAL
# ...

# %%
df
# Out:
#                    name  height   category subcat1  \
# 0        Gintoki Sakata   177.0  fictional   anime
# 1     Shinpachi Shimura   166.0  fictional   anime
# 2                Kagura   155.0  fictional   anime
# 3     Shinsuke Takasugi   170.0  fictional   anime
# 4       Kotarou Katsura   175.0  fictional   anime
# ...                 ...     ...        ...     ...
# 1632    Hikari Kohinata   148.0  fictional   anime
# 1633               Mine   155.0  fictional   anime
# 1634            Esdeath   170.0  fictional   anime
# 1635           Cornelia   168.0  fictional   anime
# 1636            Najasho   162.0  fictional   anime
#
#                                                 subcat2  \
# 0                                     Gintama THE FINAL
# 1                                     Gintama THE FINAL
# 2                                     Gintama THE FINAL
# 3                                     Gintama THE FINAL
# 4                                     Gintama THE FINAL
# ...

# %%
df.to_csv('animeready.csv', index=False)

# %%
df1 = pd.read_csv('final.csv')

# %%
df1['swap'] = df1['subcat1']
df1['swap2'] = df1['subcat2']
df1['subcat1'] = df1['swap2']
df1['subcat2'] = df1['swap']
df1.drop(columns=['swap', 'swap2'], inplace=True)

# %%
df1.to_csv('ANIME2READYTOMERGE.csv', index=False)

# %%
mergeddf = pd.merge(on='name', left=df, right=df1, how='outer')

# %%
mergeddf
# Out:
#                              name  height_x category_x subcat1_x  \
# 0                  Gintoki Sakata     177.0  fictional     anime
# 1               Shinpachi Shimura     166.0  fictional     anime
# 2                          Kagura     155.0  fictional     anime
# 3               Shinsuke Takasugi     170.0  fictional     anime
# 4                 Kotarou Katsura     175.0  fictional     anime
# ...                           ...       ...        ...       ...
# 7605  Diana Peschka Holly Eryngii       NaN        NaN       NaN
# 7606                 Harue Kasuga       NaN        NaN       NaN
# 7607                 Harue Kasuga       NaN        NaN       NaN
# 7608                 Riako Mihara       NaN        NaN       NaN
# 7609                  Toru Nayuki       NaN        NaN       NaN
#
#               subcat2_x                                           extras_x  \
# 0     Gintama THE FINAL  {'Birthday': 'Oct 10', 'Age': '27', 'Gender': ...
# ...

# %%
mergeddf
# Out:
#                     name  height   category subcat1  \
# 0                 Kagura   155.0  fictional   anime
# 1                  Sanji   177.0  fictional   anime
# 17                  Nami   169.0  fictional   anime
# 33                 Usopp   174.0  fictional   anime
# 49                 Brook   266.0  fictional   anime
# ..                   ...     ...        ...     ...
# 842          Mikan Yuuki   149.0  fictional   anime
# 858         Risa Momioka   167.0  fictional   anime
# 874         Yui Kotegawa   162.0  fictional   anime
# 890  Nana Astar Deviluke   150.0  fictional   anime
# 906             Cornelia   168.0  fictional   anime
#
#                              subcat2  \
# 0                  Gintama THE FINAL
# 1                          ONE PIECE
# 17                         ONE PIECE
# 33                         ONE PIECE
# 49                         ONE PIECE
# ..                               ...
# 842  To LOVERu Darkness 2nd Specials
# ...

# %%
newdf = pd.read_csv('merged_file.csv')

# %%
newdf
# Out:
#                         name  height   category       subcat1  \
# 0                  All Might   220.0  fictional         anime
# 1             Kuugo Sakamata   202.0  fictional         anime
# 2                   Endeavor   195.0  fictional         anime
# 3             Inasa Yoarashi   190.0  fictional         anime
# 4             Yawara Chatora   190.0  fictional         anime
# ...                      ...     ...        ...           ...
# 23060             zuri adele   170.0  celebrity       actress
# 23061              zuri hall   168.0  celebrity          show
# 23062           álvaro soler   165.0  celebrity  music_artist
# 23063  ólafur darri ólafsson   191.0  celebrity         actor
# 23064         úrsula corberó   163.0  celebrity       actress
#
#                          subcat2  \
# 0      My Hero Academia (Series)
# 1      My Hero Academia (Series)
# 2      My Hero Academia (Series)
# 3      My Hero Academia (Series)
# 4      My Hero Academia (Series)
# ...

# %%
newdf.to_json('finalDAta.json', orient='records')
